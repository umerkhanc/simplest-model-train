# %%
import requests

url = 'https://www.freesmssender.com/sendsms'

parameters = {
    'to': '+923322513911',
    'message': 'Hello, this is a test message.',
    'sender': 'TEST'
}

response = requests.get(url, params=parameters)
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File e:\python\lib\site-packages\urllib3\connection.py:169, in HTTPConnection._new_conn(self)
#     168 try:
# --> 169     conn = connection.create_connection(
#     170         (self._dns_host, self.port), self.timeout, **extra_kw
#     171     )
#     173 except SocketTimeout:
#
# File e:\python\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      69     return six.raise_from(
#      70         LocationParseError(u"'%s', label empty or too long" % host), None
#      71     )
# ---> 73 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74     af, socktype, proto, canonname, sa = res
#
# File e:\python\lib\socket.py:918, in getaddrinfo(host, port, family, type, proto, flags)
#     917 addrlist = []
# ...
